# %%
from keras.datasets import imdb
(train_data, train_label),(test_data, test_label) = imdb.load_data(num_words=10000)

# %%
import numpy as np
def vectorize(sequences, dimensions=10000):
  results = np.zeros((len(sequences), dimensions))
  for i, sequence in enumerate(sequences):
    results[i,sequence] = 1
  return results

X_train = vectorize(train_data)
X_test = vectorize(test_data)

# %%
# y_train = np.asarray(train_label).astype('float32')
# y_test = np.asarray(test_label).astype('float32')
y_train = train_label
y_test = test_label

# %%
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(16, input_shape=(10000,), activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 16)             │       160,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 160,305 (626.19 KB)
#  Trainable params: 160,305 (626.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, batch_size=512, validation_split=0.2, epochs=20, verbose=1)
# Out:
# Epoch 1/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.6785 - loss: 0.6003 - val_accuracy: 0.8830 - val_loss: 0.3300
# Epoch 2/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9141 - loss: 0.2615 - val_accuracy: 0.8932 - val_loss: 0.2753
# Epoch 3/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9425 - loss: 0.1754 - val_accuracy: 0.8936 - val_loss: 0.2761
# Epoch 4/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9583 - loss: 0.1362 - val_accuracy: 0.8884 - val_loss: 0.2953
# Epoch 5/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9680 - loss: 0.1063 - val_accuracy: 0.8832 - val_loss: 0.3207
# Epoch 6/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9772 - loss: 0.0836 - val_accuracy: 0.8804 - val_loss: 0.3498
# Epoch 7/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9826 - loss: 0.0667 - val_accuracy: 0.8788 - val_loss: 0.3828
# Epoch 8/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9878 - loss: 0.0543 - val_accuracy: 0.8754 - val_loss: 0.4184
# Epoch 9/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9915 - loss: 0.0440 - val_accuracy: 0.8738 - val_loss: 0.4567
# Epoch 10/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9953 - loss: 0.0324 - val_accuracy: 0.8726 - val_loss: 0.4884
# Epoch 11/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9970 - loss: 0.0266 - val_accuracy: 0.8722 - val_loss: 0.5267
# Epoch 12/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9980 - loss: 0.0220 - val_accuracy: 0.8706 - val_loss: 0.5604
# Epoch 13/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9988 - loss: 0.0166 - val_accuracy: 0.8672 - val_loss: 0.6000
# Epoch 14/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9988 - loss: 0.0141 - val_accuracy: 0.8710 - val_loss: 0.6352
# Epoch 15/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9995 - loss: 0.0102 - val_accuracy: 0.8698 - val_loss: 0.6760
# Epoch 16/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9998 - loss: 0.0084 - val_accuracy: 0.8682 - val_loss: 0.7045
# Epoch 17/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9999 - loss: 0.0064 - val_accuracy: 0.8698 - val_loss: 0.7415
# Epoch 18/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.8680 - val_loss: 0.7695
# Epoch 19/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.8678 - val_loss: 0.7930
# Epoch 20/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.8666 - val_loss: 0.8186

# %%
bce , a = model.evaluate(X_test, y_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8537 - loss: 0.8748

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# array([[3.7739094e-02],
#        [1.0000000e+00],
#        [4.6524123e-04],
#        ...,
#        [1.4836750e-02],
#        [9.3667232e-04],
#        [9.2829533e-02]], dtype=float32)

# %%
# tests = []
# for i in y_test:
#   tests.append(int(i))

# %%
preds = []
for i in y_pred:
  if i[0] > 0.5:
    preds.append(1)
  else:
    preds.append(0)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85     12500
#            1       0.86      0.84      0.85     12500
#
#     accuracy                           0.85     25000
#    macro avg       0.85      0.85      0.85     25000
# weighted avg       0.85      0.85      0.85     25000

# %%
word_index = imdb.get_word_index()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# word_index
len(word_index)
# Out:
# 88584
